# %% [markdown]
# 1. SQL Bağlantısı ile Veri Çekme

# %%
# %pip install dash
# %pip install dash_bootstrap_components
# %pip install dash-core-components

# %%
# %pip install dash-table
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install plotly

# %%
# %pip install xlsxwriter
# %pip install openpyxl

# %%
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dash
from dash import dash_table, dcc, html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
from plotly import graph_objects as go
import plotly.express as px
import warnings
import socket #IP adresimi yakalayabilmek için.
import dash_html_components as html
import webbrowser # Yeni sekmede açmak için.
import io # İndirme butonu için.
import base64 # İndirme butonu için.
from flask import send_file # Excel olarak indirebilmek için.
# Out:
# C:\Users\kerem\AppData\Local\Temp\ipykernel_14536\103343713.py:13: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
cnxn_str = ("Driver={SQL Server};Server=DESKTOP-RLE9BEF;Database=AdventureWorks2022;Trusted_Connection=yes;")
cnxn = pyodbc.connect(cnxn_str)

# %%
Sorgu = "SELECT * FROM [AdventureWorks2022].[Production].[Product]"

# %%
df = pd.read_sql(Sorgu, cnxn)
df
# Out:
# C:\Users\kerem\AppData\Local\Temp\ipykernel_5412\1322320532.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(Sorgu, cnxn)
#      ProductID                   Name ProductNumber  MakeFlag  \
# 0            1        Adjustable Race       AR-5381     False
# 1            2           Bearing Ball       BA-8327     False
# 2            3        BB Ball Bearing       BE-2349      True
# 3            4  Headset Ball Bearings       BE-2908     False
# 4          316                  Blade       BL-2036      True
# ..         ...                    ...           ...       ...
# 499        995      ML Bottom Bracket       BB-8107      True
# 500        996      HL Bottom Bracket       BB-9108      True
# 501        997     Road-750 Black, 44    BK-R19B-44      True
# ...

# %% [markdown]
# 2. Görselleştirme

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go

# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Sayfa düzenini tanımlama
app.layout = html.Div([
    html.H1('Dashboard Başlığı'),

    # Genel filtreler
    html.Div([
        dcc.Dropdown(
            id='filter1',
            options=[
                {'label': 'Filtre 1', 'value': 'value1'},
                {'label': 'Filtre 2', 'value': 'value2'},
                {'label': 'Filtre 3', 'value': 'value3'}
            ],
            value='value1'
        ),
        dcc.Dropdown(
            id='filter2',
            options=[
                {'label': 'Filtre 4', 'value': 'value4'},
                {'label': 'Filtre 5', 'value': 'value5'},
                {'label': 'Filtre 6', 'value': 'value6'}
            ],
            value='value4'
        ),
        dcc.Dropdown(
            id='filter3',
            options=[
                {'label': 'Filtre 7', 'value': 'value7'},
                {'label': 'Filtre 8', 'value': 'value8'},
                {'label': 'Filtre 9', 'value': 'value9'}
            ],
            value='value7'
        )
    ]),

    # Grafik 1
    dcc.Graph(
        id='graph1',
        figure={
            'data': [
                go.Scatter(
                    x=[1, 2, 3, 4, 5],
                    y=[2, 4, 1, 5, 3],
                    mode='lines',
                    name='Data 1'
                )
            ],
            'layout': go.Layout(
                title='Grafik 1 Başlığı',
                xaxis={'title': 'X Ekseni'},
                yaxis={'title': 'Y Ekseni'}
            )
        }
    ),

    # Grafik 2
    dcc.Graph(
        id='graph2',
        figure={
            'data': [
                go.Bar(
                    x=['A', 'B', 'C'],
                    y=[3, 2, 5],
                    name='Data 2'
                )
            ],
            'layout': go.Layout(
                title='Grafik 2 Başlığı',
                xaxis={'title': 'Kategoriler'},
                yaxis={'title': 'Değerler'}
            )
        }
    ),

    # Grafik 3
    dcc.Graph(
        id='graph3',
        figure={
            'data': [
                go.Pie(
                    labels=['Kategori 1', 'Kategori 2', 'Kategori 3'],
                    values=[40, 30, 20],
                    hole=0.3
                )
            ],
            'layout': go.Layout(
                title='Grafik 3 Başlığı'
            )
        }
    )
])

# Uygulamayı çalıştırma
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# 2.2. Görselleştirme

# %%
# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

df = pd.read_sql(Sorgu, cnxn)
df

app.layout = html.Div([
    html.H6('DENEME DASHBOARD'),


    

    html.Div([
        # Tablomuz :
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in df.columns],
                data=df.to_dict('records')
            )
        ])
    ], className='row'),

    html.Div([
        # Grafikler :
        html.Div([
            # Grafik 1 :
            html.Div([
                dcc.Graph(
                    id='graph1',
                    figure={
                        'data': [
                            {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                        ],
                        'layout': {
                            'title': 'Yaş Dağılımı'
                        }
                    }
                )
            ], className='six columns'),

            # Grafik 2 :
            html.Div([
                dcc.Graph(
                    id='graph2',
                    figure={
                        'data': [
                            {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                        ],
                        'layout': {
                            'title': 'Şehir Dağılımı'
                        }
                    }
                )
            ], className='six columns')
        ], className='row')
    ])
])


# Uygulamayı çalıştırma kısmı :
if __name__ == '__main__':
    # IP adresini alıyoruz.
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdırıyoruz.
    print(f"Uygulama çalışıyor - http://{ip_address}:8050/")
    
    # Uygulamayı çalıştırma :
    app.run_server(host=ip_address, port=8050, debug=True)

# %% [markdown]
# 2.3. Görselleştirme

# %%
# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

# df = pd.read_sql(Sorgu, cnxn)


# Tablonun ilk 10 satırını al
limited_df = df.head(10)

app.layout = html.Div([
    html.H1('DENEME DASHBOARD', 
            style={
                'color': '#1D2D44',
                'font-size': '40px',
                'font-family': 'Arial, sans-serif',
                'font-weight': 'bold',
                'text-align': 'center',
                'text-transform': 'uppercase',
                'text-decoration': 'underline',
                'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                'letter-spacing': '2px', # Harfler arasındaki boşluğu belirler.
                'line-height': '1.5', # Satırın yüksekliğini belirler.
            }
    ),

    html.Div([
        # Tablo
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in limited_df.columns],
                data=limited_df.to_dict('records')
            )
        ])
    ], className='row'),

    html.Div([
        # Tablo detay butonu
        html.Div([
            html.A('Tablonun Tamamı İçin Tıklayınız', 
                   #id='download-button',
                   href='/full-table',
                   target='_blank',
                   style={
                       'background-color': '#748CAB',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin-top': '10px',
                       'margin-bottom': '10px'
                   })
        ], style={'text-align': 'center', 'margin-top': '20px'}),
        
        # Tabloyu indirme butonu
        html.Div([
            html.A('Tabloyu İndirmek İçin Tıklayınız', 
                   id='download-link',
                   href='',
                   target='_blank',
                   style={
                       'background-color': '#1D2D44',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin-top': '10px',
                       'margin-bottom': '10px'
                   })
        ], style={'text-align': 'center', 'margin-top': '10px'})
    ], className='row'),

    html.Div([
        # Grafik 1
        html.Div([
            dcc.Graph(
                id='graph1',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                    ],
                    'layout': {
                        'title': 'Yaş Dağılımı'
                    }
                }
            )
        ], className='six columns'),

        # Grafik 2
        html.Div([
            dcc.Graph(
                id='graph2',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                    ],
                    'layout': {
                        'title': 'Şehir Dağılımı'
                    }
                }
            )
        ], className='six columns')
    ], className='row')
])

# Excel formatında indirmek için :
@app.callback(Output('download-link', 'href'),
              [Input('download-button', 'n_clicks')])
def download_table(n_clicks):
    if n_clicks is None:
        return ''
    else:
        # Tabloyu excel formatına dönüştür
        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
            df.to_excel(writer, index=False)
        output.seek(0)
        
        # Dosya objesini base64 formatına dönüştür
        excel_base64 = base64.b64encode(output.read()).decode('utf-8')
        
        # İndirme bağlantısını oluştur
        return f'data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;base64,{excel_base64}'



@app.server.route('/full-table')
def show_full_table_route():
    return df.to_html()


# Uygulamayı çalıştırma
if __name__ == '__main__':
    # IP adresini al
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdır
    print(f"Uygulama çalışıyor - http://{ip_address}:8050/")
    
    # Uygulamayı çalıştır
    app.run_server(host=ip_address, port=8050, debug=True)

# %% [markdown]
# 2.4 Görselleştirme

# %%
# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

# df = pd.read_sql(Sorgu, cnxn)

# Tablonun ilk 10 satırını al
limited_df = df.head(10)

# Dashboard main class
app.layout = html.Div([

    # Dashboard başlığım
    html.H1('DENEME DASHBOARD', 
            style={
                'color': '#1D2D44',
                'font-size': '40px',
                'font-family': 'Arial, sans-serif',
                'font-weight': 'bold',
                'text-align': 'center',
                'text-transform': 'uppercase',
                'text-decoration': 'underline',
                'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                'letter-spacing': '2px', # Harfler arasındaki boşluğu belirler.
                'line-height': '1.5', # Satırın yüksekliğini belirler.
            }
    ),

    # Tablom
    html.Div([
        # Tablo
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in limited_df.columns],
                data=limited_df.to_dict('records')
            )
        ])
    ], className='row'),

    # Butonlarım
    html.Div([
        html.Div(
            html.A('Tablonun Tamamı İçin Tıklayınız', 
                   href='/full-table',
                   target='_blank',
                   #className='button',
                   style={
                       'background-color': '#748CAB',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px', # yukarı ve aşağı 10px, sağa ve sola 20px boşluk bırakır. Yazı ile kenar arasında.
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        ),
        
        html.Div(
            html.A('Tabloyu İndirmek İçin Tıklayınız', 
                   id='download-link',
                   href='',
                   target='_blank',
                   download='table.xlsx',
                   #className='button',
                   style={
                       'background-color': '#1D2D44',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        )
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'}),

    # Grafiklerim
    
    html.Div([
        # Grafik 1
        html.Div([
            dcc.Graph(
                id='graph1',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                    ],
                    'layout': {
                        'title': 'Yaş Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'}),

        # Grafik 2
        html.Div([
            dcc.Graph(
                id='graph2',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                    ],
                    'layout': {
                        'title': 'Şehir Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'})
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'})
])



# Excel formatında indirmek için callback fonksiyonunu kullanıyorum :
@app.callback(Output('download-link', 'href'),
              [Input('download-link', 'n_clicks')])
def download_table(n_clicks):
    if n_clicks is None:
        return ''
    else:
        # Tabloyu excel formatına dönüştürür
        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='openpyxl') as writer:
            pd.DataFrame(np.array(df), columns=df.columns).to_excel(writer, index=False)
        output.seek(0)

        # Dosya objesini base64 formatına dönüştürür
        excel_base64 = base64.b64encode(output.read()).decode('utf-8')

        # İndirme bağlantısını oluşturur
        return f'data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;charset=utf-8;base64,{excel_base64}'


# Yeni sayfada tüm tabloyu açar.
@app.server.route('/full-table')
def show_full_table_route():
    return df.to_html()


# Uygulamayı çalıştırma :
if __name__ == '__main__':
    # IP adresini alır.
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdırır.
    print(f"Adress : http://{ip_address}:8050/")
    
    # Uygulamayı çalıştırır.
    app.run_server(host=ip_address, port=8050, debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 39
#      14 limited_df = df.head(10)
#      16 # Dashboard main class
#      17 app.layout = html.Div([
#      18
#      19     # Dashboard başlığım
#      20     html.H1('DENEME DASHBOARD',
#      21             style={
#      22                 'color': '#1D2D44',
#      23                 'font-size': '40px',
#      24                 'font-family': 'Arial, sans-serif',
#      25                 'font-weight': 'bold',
#      26                 'text-align': 'center',
#      27                 'text-transform': 'uppercase',
#      28                 'text-decoration': 'underline',
#      29                 'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
#      30                 'letter-spacing': '2px', # Harfler arasındaki boşluğu belirler.
# ...

# %% [markdown]
# 2.5. Görselleştirme

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

# Tablonun ilk 10 satırını al
limited_df = df.head(10)

# Dashboard main class
app.layout = html.Div([

    # Dashboard başlığım
    html.H1('DENEME DASHBOARD',
            style={
                'color': '#1D2D44',
                'font-size': '40px',
                'font-family': 'Arial, sans-serif',
                'font-weight': 'bold',
                'text-align': 'center',
                'text-transform': 'uppercase',
                'text-decoration': 'underline',
                'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                'letter-spacing': '2px',  # Harfler arasındaki boşluğu belirler.
                'line-height': '1.5',  # Satırın yüksekliğini belirler.
            }
            ),

    # Tablom
    html.Div([
        # Tablo
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in limited_df.columns],
                data=limited_df.to_dict('records')
            )
        ])
    ], className='row'),

    # Butonlarım
    html.Div([
        html.Div(
            html.A('Tablonun Tamamı İçin Tıklayınız', 
                   href='/full-table',
                   target='_blank',
                   #className='button',
                   style={
                       'background-color': '#748CAB',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px', # yukarı ve aşağı 10px, sağa ve sola 20px boşluk bırakır. Yazı ile kenar arasında.
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        ),
        
        html.Div(
            html.A('Tabloyu İndirmek İçin Tıklayınız', 
                   id='download-link',
                   href='',
                   target='_blank',
                   download='table.xlsx',
                   #className='button',
                   style={
                       'background-color': '#1D2D44',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        )
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'}),


    # Grafiklerim
    
    html.Div([
        # Grafik 1
        html.Div([

            # Filtre
            html.Div([
            dcc.RangeSlider(
            id='age-slider',
            min=df['Age'].min(),
            max=df['Age'].max(),
            value=[df['Age'].min(), df['Age'].max()],
            marks={str(age): str(age) for age in df['Age'].unique()},
            step=None
        )
        ], style={'justify-content': 'center','margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph(
                id='graph1',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                    ],
                    'layout': {
                        'title': 'Yaş Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'}),

        # Grafik 2
        html.Div([

            # Filtre
            html.Div([ 
            dcc.Dropdown(
            id='city-dropdown',
            options=[{'label': city, 'value': city} for city in df['City'].unique()],
            value=df['City'].unique().tolist(),
            multi=True
        )
        ], style={'justify-content': 'center','margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph( 
                id='graph2',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                    ],
                    'layout': {
                        'title': 'Şehir Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'})
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'})
])



# Filtre 1
@app.callback(
    dash.dependencies.Output('graph1', 'figure'),
    [dash.dependencies.Input('age-slider', 'value')]
)
def update_graph1(selected_age):
    filtered_df = df[df['Age'] <= selected_age]
    figure = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['Age'], 'type': 'bar', 'name': 'Yaş'}
        ],
        'layout': {
            'title': 'Yaş Dağılımı ({} ve daha küçük)'.format(selected_age)
        }
    }
    return figure

# Filtre 1
@app.callback(
    dash.dependencies.Output('graph2', 'figure'),
    [dash.dependencies.Input('city-dropdown', 'value')]
)
def update_graph2(selected_city):
    filtered_df = df[df['City'] == selected_city]
    figure = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
        ],
        'layout': {
            'title': 'Şehir Dağılımı ({})'.format(selected_city)
        }
    }
    return figure

# Excel formatında indirmek için callback fonksiyonunu kullanıyorum :
@app.callback(Output('download-link', 'href'),
              [Input('download-link', 'n_clicks')])
def download_table(n_clicks):
    if n_clicks is None:
        return ''
    else:
        # Tabloyu excel formatına dönüştürür
        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='openpyxl') as writer:
            pd.DataFrame(np.array(df), columns=df.columns).to_excel(writer, index=False)
        output.seek(0)

        # Dosya objesini base64 formatına dönüştürür
        excel_base64 = base64.b64encode(output.read()).decode('utf-8')

        # İndirme bağlantısını oluşturur
        return f'data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;charset=utf-8;base64,{excel_base64}'


# Yeni sayfada tüm tabloyu açar.
@app.server.route('/full-table')
def show_full_table_route():
    return df.to_html()


# Uygulamayı çalıştırma :
if __name__ == '__main__':
    # IP adresini alır.
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdırır.
    print(f"Adress : http://{ip_address}:8050/")
    
    # Uygulamayı çalıştırır.
    app.run_server(host=ip_address, port=8050, debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 42
#      17 limited_df = df.head(10)
#      19 # Dashboard main class
#      20 app.layout = html.Div([
#      21
#      22     # Dashboard başlığım
#      23     html.H1('DENEME DASHBOARD',
#      24             style={
#      25                 'color': '#1D2D44',
#      26                 'font-size': '40px',
#      27                 'font-family': 'Arial, sans-serif',
#      28                 'font-weight': 'bold',
#      29                 'text-align': 'center',
#      30                 'text-transform': 'uppercase',
#      31                 'text-decoration': 'underline',
#      32                 'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
#      33                 'letter-spacing': '2px',  # Harfler arasındaki boşluğu belirler.
# ...

# %% [markdown]
# 2.6. Görselleştirme

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

# Tablonun ilk 10 satırını al
limited_df = df.head(10)

# Dashboard main class
app.layout = html.Div([

    # Dashboard başlığım
    html.H1('DENEME DASHBOARD',
            style={
                'color': '#1D2D44',
                'font-size': '40px',
                'font-family': 'Arial, sans-serif',
                'font-weight': 'bold',
                'text-align': 'center',
                'text-transform': 'uppercase',
                'text-decoration': 'underline',
                'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                'letter-spacing': '2px',  # Harfler arasındaki boşluğu belirler.
                'line-height': '1.5',  # Satırın yüksekliğini belirler.
            }
            ),

    # Tablom
    html.Div([
        # Tablo
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in limited_df.columns],
                data=limited_df.to_dict('records')
            )
        ])
    ], className='row'),

    # Butonlarım
    html.Div([
        html.Div(
            html.A('Tablonun Tamamı İçin Tıklayınız', 
                   href='/full-table',
                   target='_blank',
                   #className='button',
                   style={
                       'background-color': '#748CAB',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px', # yukarı ve aşağı 10px, sağa ve sola 20px boşluk bırakır. Yazı ile kenar arasında.
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        ),
        
        html.Div(
            html.A('Tabloyu İndirmek İçin Tıklayınız', 
                   id='download-link',
                   href='',
                   target='_blank',
                   download='table.xlsx',
                   #className='button',
                   style={
                       'background-color': '#1D2D44',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        )
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'}),


    # Grafiklerim
    
    html.Div([
        # Grafik 1
        html.Div([

            # Filtre
            html.Div([
            dcc.RangeSlider(
                id='age-slider',
                min=df['Age'].min(),
                max=df['Age'].max(),
                value=[df['Age'].min(), df['Age'].max()],
                marks={str(age): str(age) for age in df['Age'].unique()},
                step=None
            )
        ], style={'margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph(
                id='graph1',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                    ],
                    'layout': {
                        'title': 'Yaş Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'}),

        # Grafik 2
        html.Div([

            # Filtre
            html.Div([
            dcc.Dropdown(
                id='city-dropdown',
                options=[{'label': city, 'value': city} for city in df['City'].unique()],
                value=df['City'].unique().tolist(),
                multi=True
            )
        ], style={'margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph( 
                id='graph2',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                    ],
                    'layout': {
                        'title': 'Şehir Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'})
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'})
])



# Yaş filtresi:
@app.callback(
    Output('graph1', 'figure'),
    [Input('age-slider', 'value')]
)
def update_age_graph(age_range):
    filtered_df = df[(df['Age'] >= age_range[0]) & (df['Age'] <= age_range[1])]
    
    fig = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['Age'], 'type': 'bar', 'name': 'Yaş'}
        ],
        'layout': {
            'title': 'Yaş Dağılımı'
        }
    }
    
    return fig

# Şehir filtresi:
@app.callback(
    Output('graph2', 'figure'),
    [Input('city-dropdown', 'value')]
)
def update_city_graph(selected_cities):
    filtered_df = df[df['City'].isin(selected_cities)]
    
    fig = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
        ],
        'layout': {
            'title': 'Şehir Dağılımı'
        }
    }
    
    return fig



# Excel formatında indirmek için callback fonksiyonunu kullanıyorum :
@app.callback(Output('download-link', 'href'),
              [Input('download-link', 'n_clicks')])
def download_table(n_clicks):
    if n_clicks is None:
        return ''
    else:
        # Tabloyu excel formatına dönüştürür
        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='openpyxl') as writer:
            pd.DataFrame(np.array(df), columns=df.columns).to_excel(writer, index=False)
        output.seek(0)

        # Dosya objesini base64 formatına dönüştürür
        excel_base64 = base64.b64encode(output.read()).decode('utf-8')

        # İndirme bağlantısını oluşturur
        return f'data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;charset=utf-8;base64,{excel_base64}'


# Yeni sayfada tüm tabloyu açar.
@app.server.route('/full-table')
def show_full_table_route():
    return df.to_html()


# Uygulamayı çalıştırma :
if __name__ == '__main__':
    # IP adresini alır.
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdırır.
    print(f"Adress : http://{ip_address}:8050/")
    
    # Uygulamayı çalıştırır.
    app.run_server(host=ip_address, port=8050, debug=True)
# Out:
# C:\Users\kerem\AppData\Local\Temp\ipykernel_37080\1626204059.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\kerem\AppData\Local\Temp\ipykernel_37080\1626204059.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 42
#      17 limited_df = df.head(10)
#      19 # Dashboard main class
#      20 app.layout = html.Div([
#      21
#      22     # Dashboard başlığım
#      23     html.H1('DENEME DASHBOARD',
#      24             style={
#      25                 'color': '#1D2D44',
#      26                 'font-size': '40px',
# ...

# %% [markdown]
# DENEME

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# Dash uygulamasını başlatma
app = dash.Dash(__name__)

# Örnek DataFrame'i oluşturma
df = pd.DataFrame({
    'Name': ['John', 'Jane', 'Mike', 'Emily'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
})

# Tablonun ilk 10 satırını al
limited_df = df.head(10)

# Dashboard main class
app.layout = html.Div([

    # Dashboard başlığım
    html.H1('DENEME DASHBOARD',
            style={
                'color': '#1D2D44',
                'font-size': '40px',
                'font-family': 'Arial, sans-serif',
                'font-weight': 'bold',
                'text-align': 'center',
                'text-transform': 'uppercase',
                'text-decoration': 'underline',
                'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                'letter-spacing': '2px',  # Harfler arasındaki boşluğu belirler.
                'line-height': '1.5',  # Satırın yüksekliğini belirler.
            }
            ),

    # Tablom
    html.Div([
        # Tablo
        html.Div([
            dash_table.DataTable(
                id='table',
                columns=[{'name': col, 'id': col} for col in limited_df.columns],
                data=limited_df.to_dict('records')
            )
        ])
    ], className='row'),

    # Butonlarım
    html.Div([
        html.Div(
            html.A('Tablonun Tamamı İçin Tıklayınız', 
                   href='/full-table',
                   target='_blank',
                   #className='button',
                   style={
                       'background-color': '#748CAB',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px', # yukarı ve aşağı 10px, sağa ve sola 20px boşluk bırakır. Yazı ile kenar arasında.
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        ),
        
        html.Div(
            html.A('Tabloyu İndirmek İçin Tıklayınız', 
                   id='download-link',
                   href='',
                   target='_blank',
                   download='table.xlsx',
                   #className='button',
                   style={
                       'background-color': '#1D2D44',
                       'color': 'white',
                       'display': 'inline-block',
                       'padding': '10px 20px',
                       'border-radius': '10px',
                       'border': '2px solid #3E5C76',
                       'text-shadow': '2px 2px 4px rgba(0, 0, 0, 0.5)',
                       'box-shadow': '0px 5px 5px rgba(0, 0, 0, 0.5)',
                       'text-align': 'center',
                       'margin': '10px'
                   })
        )
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'}),


    # Grafiklerim
    
    html.Div([
        # Grafik 1
        html.Div([

            # Filtre
            html.Div([
            dcc.RangeSlider(
                id='age-slider',
                min=df['Age'].min(),
                max=df['Age'].max(),
                value=[df['Age'].min(), df['Age'].max()],
                marks={str(age): str(age) for age in df['Age'].unique()},
                step=None
            )
        ], style={'margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph(
                id='graph1',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['Age'], 'type': 'bar', 'name': 'Yaş'}
                    ],
                    'layout': {
                        'title': 'Yaş Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'}),

        # Grafik 2
        html.Div([

            # Filtre
            html.Div([
            dcc.Dropdown(
                id='city-dropdown',
                options=[{'label': city, 'value': city} for city in df['City'].unique()],
                value=df['City'].unique().tolist(),
                multi=True
            )
        ], style={'margin-top': '20px', 'margin-bottom': '20px', 'width': '50%'}),

            # Grafik
            dcc.Graph( 
                id='graph2',
                figure={
                    'data': [
                        {'x': df['Name'], 'y': df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
                    ],
                    'layout': {
                        'title': 'Şehir Dağılımı'
                    }
                }
            )
        ], className='six columns', style={'width': '50%', 'height': '300px'})
    ], className='row', style={'display': 'flex', 'justify-content': 'center', 'margin-top': '20px', 'margin-bottom': '20px'})
])



# Yaş filtresi:
@app.callback(
    Output('graph1', 'figure'),
    [Input('age-slider', 'value')]
)
def update_age_graph(age_range):
    filtered_df = df[(df['Age'] >= age_range[0]) & (df['Age'] <= age_range[1])]
    
    fig = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['Age'], 'type': 'bar', 'name': 'Yaş'}
        ],
        'layout': {
            'title': 'Yaş Dağılımı'
        }
    }
    
    return fig

# Şehir filtresi:
@app.callback(
    Output('graph2', 'figure'),
    [Input('city-dropdown', 'value')]
)
def update_city_graph(selected_cities):
    filtered_df = df[df['City'].isin(selected_cities)]
    
    fig = {
        'data': [
            {'x': filtered_df['Name'], 'y': filtered_df['City'], 'type': 'scatter', 'mode': 'markers', 'name': 'Şehir'}
        ],
        'layout': {
            'title': 'Şehir Dağılımı'
        }
    }
    
    return fig



# Excel formatında indirmek için callback fonksiyonunu kullanıyorum :
@app.callback(Output('download-link', 'href'),
              [Input('download-link', 'n_clicks')])
def download_table(n_clicks):
    if n_clicks is None:
        return ''
    else:
        # Tabloyu excel formatına dönüştürür
        output = io.BytesIO()
        with pd.ExcelWriter(output, engine='openpyxl') as writer:
            pd.DataFrame(np.array(df), columns=df.columns).to_excel(writer, index=False)
        output.seek(0)

        # Dosya objesini base64 formatına dönüştürür
        excel_base64 = base64.b64encode(output.read()).decode('utf-8')

        # İndirme bağlantısını oluşturur
        return f'data:application/vnd.openxmlformats-officedocument.spreadsheetml.sheet;charset=utf-8;base64,{excel_base64}'


# Yeni sayfada tüm tabloyu açar.
@app.server.route('/full-table')
def show_full_table_route():
    return df.to_html()


# Uygulamayı çalıştırma :
if __name__ == '__main__':
    # IP adresini alır.
    hostname = socket.gethostname()
    ip_address = socket.gethostbyname(hostname)

    # IP adresini ve port numarasını yazdırır.
    print(f"Adress : http://{ip_address}:8050/")
    
    # Uygulamayı çalıştırır.
    app.run_server(host=ip_address, port=8050, debug=True)
# Out:
# Adress : http://192.168.1.31:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://192.168.1.31:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
